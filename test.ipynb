# %%
# %load_ext autoreload
# %autoreload 2
from spenpy.spen import *
import torch
from PIL import Image
import numpy as np
import math
from torchvision import transforms
from mrspy.plot import plot

image_path = '/home/data1/musong/workspace/python/spenpy/spenpy/data/water.jpg'
image = Image.open(image_path)

transform = transforms.ToTensor()

tensor_image = transform(image)

a = V1()


im_even = a.hardcode(tensor_image)


plot(np.array(image))
plot(torch.abs(im_even)[0])
# Out:
# /home/data1/musong/envs/main/lib/python3.11/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /home/data1/musong/workspace/python/spenpy/spenpy/spen.py:294: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at ../aten/src/ATen/native/Copy.cpp:299.)
#   KspaceTestZero[:, stard_idx_zero_x : end_idx_zero_x, stard_idx_zero_y : end_idx_zero_y] = KspaceTest[:, stard_idx_x : end_idx_x, stard_idx_y : end_idx_y]

# %%
alfa = -47.1239
L = [4, 4]
Finalryxacq = torch.zeros((256, 256))

aSign = -1
InvA, AFinal = calcInvA(alfa, L[1], Finalryxacq.size(0), 0, -aSign, 0, 0.9)

# %%
plot(np.array(image))
plot(torch.abs(im_even)[0])
plot(torch.abs(torch.matmul(InvA, im_even)[0]))
